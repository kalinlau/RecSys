# %% [markdown]
# # RecSys Schedule
# ---
#
# ## Resource
# ---
# 1. [RSPapers](https://github.com/hongleizhang/RSPapers)
# 1. [Microsoft/Recommenders](https://github.com/Microsoft/Recommenders)
# 1. [grahamjenson/list_of_recommender_systems](https://github.com/grahamjenson/list_of_recommender_systems)
# 1. [smore](https://github.com/cnclabs/smore): several baseline codes.
#
# ## Survey
# ---
# 1. [A Survey on Session-based Recommender Systems](https://arxiv.org/pdf/1902.04864.pdf)
#
#
# ## TKDE[J]
# ---
# 1. Heterogeneous Information Network Embedding for Recommendation.
# 1. A Location-Query-Browse Graph for Contextual Recommendation
# 1. Efficient Recommendation of Aggregate Data Visualizations.
# 1. TaxiRec: Recommending Road Clusters to Taxi Drivers Using Ranking-Based Extreme Learning Machines.
# 1. A Unified View of Social and Temporal Modeling for B2B Marketing Campaign Recommendation.
# 1. Exploring Hierarchical Structures for Recommender Systems.
# 1. Scalable Content-Aware Collaborative Filtering for Location Recommendation.
# 1. Privacy Enhanced Matrix Factorization for Recommendation with Local Differential Privacy
# 1. A New Query Recommendation Method Supporting Exploratory Search Based on Search Goal Shift Graphs.
# 1. A General Framework for Implicit and Explicit Social Recommendation
# 1. NAIS: Neural Attentive Item Similarity Model for Recommendation
#
# ## CIKM
# ---
# 1. RippleNet: Propagating User Preferences on the Knowledge Graph for Recommender Systems. Hongwei Wang, Fuzheng Zhang, Jialin Wang, Miao Zhao, Wenjie Li, Xing Xie, Minyi Guo. CIKM 2018.
#
# ## KDD(CCF A) <b style="color:gold">[Paper not released]</b>
# ---
# ### Tutorials
# 1. [Social User Interest Mining: Methods and Applications](http://ls3.rnet.ryerson.ca/?p=962)
# 1. [Constructing and Mining Heterogeneous Information Networks from Massive Text](https://shangjingbo1226.github.io/2019-04-22-kdd-tutorial/)
# > <b style="color:gold">[preliminary version]</b>
# 1. [Foundations of large-scale sequential experimentation](http://stat.cmu.edu/~aramdas/kdd19/)
# 1. [Deep Natural Language Processing for Search and Recommender Systems](https://sites.google.com/view/kdd2019deepnlp)
#
# ## ICDE(CCF A)
# ---
# 1. [A Generic Top-N Recommendation Framework for Trading-Off Accuracy, Novelty, and Coverage](https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=8509244)
#
# ## SIGIR(CCF A)
# ---
#
# ## ICDM(CCF B)
# ---
#
# ## WSDM(CCF B)
# ---
# 1. <b style="color:#2874A6">A General View for Network Embedding as Matrix Factorization</b>
#    1. workind: To
#    1. topics:
#    1. que: model relation of NE and MF
#    1. contr: general view of relationship between NE and MF
#       1. propose an objective function with two sub-objectives
#       1. propose a new similarity measurement
#    1. review:
#       1. This paper belongs to <b style="color:green">theory-oriented</b> category,
#          which offers a general view of relationship between NE and MF. NE and MF
#          are generally studied and put together to solve lots of real application like
#          cummunity detection, recommendation, etc.
#       1. feeling of this "theory-oriented" paper: not superising at all, and so does the
#          crativity. But it actually offers new methodology of idea clues: <b style="color:red">
#          Unify similar methods and find out the basic underlying mechanism</b>
#    1. keynote:
# 1. <b style="color:#2874A6">RecWalk: Nearly Uncoupled Random Walks for Top-N Recommendation</b>
#    1. workind: Ao
#    1. topics: item-based CF
#    1. que:
#       1. existing RandomWalk-based methods focus on the central nodes of graph
#       1. this restrict the range of random walk
#    1. contri:
#       1. adjust random walk mechanism to extend walking range.
#       1. [OpenSource](https://github.com/nikolakopoulos/RecWalk)
#    1. data:
#       1. movielens
#       1. yahoo's subset: Yahoo!R2Music
#       1. [pinterest](https://github.com/hexiangnan/neural_collaborative_filtering)
#    1. review:
#       1. IdeaClue: shortage-->que-->model
#          > Item-based RecSys is scalable and interpretable, but only consider direct connection;
#            $\Longrightarrow$ use random walk, to extend range of connection, including undirect ones
#
#       1. the author believes what random walk offers is mitigation of data sparsity.
#    1. keynote:
#
# 1. <b style="color:#2874A6">Social Attentional Memory Network: Modeling Aspect- and Friend-Level Differences in Recommendation</b>
#    1. workind: Ao
#    1. topics: SocR
#    1. que:
#       1. pho:
#          1. one's friends only affect his/her preference in some aspect
#          1. friends are not equally important
#       1. que: current Social RecSys not model this 2 pho.
#    1. contri: <b style="color:gray">$\Longrightarrow$good story</b>
#       1. attention-based memory module $\Longrightarrow$ pho1 by attention, by memory
#       1. friend-level attention component $\Longrightarrow$ pho2 by attention
#    1. data
#       1. [Delicious](https://grouplens.org/datasets/hetrec-2011/)
#       1. Ciao
#       1. Epinions
#    1. review:
#       1. IdeaClue: pho-->que-->hypt-->model
#       1. typical Ao: use existing methods to solve/model new phenomenon/story
#    1. keynote:
# 1. <b style="color:#2874A6">Spiral of Silence in Recommender Systems</b>
#     1. que:
#        1. workind: To/CDo
#        1. phenomenon:
#           1. ratings are missing not at random(MNAR assumption)
#           1. existing MNAR models mimic rating generation under different heuristics
#           1. heuristics is used but not varified, neither are any theoretical studies given
#        1. goal:
#           1. explanation of MNAR phenomenon <b style="color:gray">$\Longrightarrow$ Spiral of Silence Theory</b>
#           1. identify key factor underlying decision making process whether rate or not
#              <b style="color:gray">$\Longrightarrow$ opinion climate, persona</b>
#           1. demonstrate the impact of the empirical study.
#              <b style="color:gray">$\Longrightarrow$ by develope a model to mimics the generation process
#              of rating and responses</b>
#     1. data: 8 real datasets
#        1. Yahoo!random
#     1. contr:
#        1. empirically examine <b style="color:gray">Spiral of Silence Theory</b> in MNAR
#        1. develop a new model with MNAR assumptions
#     1. review:
#        1. ideaClue: phen-->que-->[borrow a guaranting theory-->empirically varify theory](Theory)
#                     -->[develope new model --> varify model](Application)
#        1. que: 从控制变量的角度分析这两个贡献的验证试验，效果有待检查: MNAR假设是否一致？
#        1. 借助社会学，心理学理论研究推荐问题背后的成因，这个思路挺好
#     1. keynote:
# 1. <b style="color:#2874A6">Fighting Fire with Fire: Using Antidote Data to Improve Polarization and Fairness of Recommender Systems</b>
#    1. workind: Ao
#    1. topics: multi-criterion, anti-social attacks
#    1. que: whether augmenting input with additional data can improve social desirability of recommendations
#       1. recsys useful
#       1. CF algo used and its shortage
#       1. previous methods: data transformation
#       1. ours: add additional
#    1. data
#    1. contri
#       1. a generic frames used to improve multi-criterion of RecSys: polarization, fairness
#       1. extend previous anti-social techs to augment tech
#       1. propese metrices for multi-criterion
#       1. generate antidote data
#    1. reviews:
#       1. <b style="color:red">valuable</b>
#       1. IdeaClue: shortage-->que-->model
#          1. shortage: modification either input, system or output to adapt different criterion
#             1. not easy
#             1. not extendable for 3rd parties
#             1. not applicable to a wide range of socially relevant criterion
#          1. can we augment by additional data
#          1. model: antidote frames
#       1. <b style="color:gold">how do they design experiment?</b>
#          > 本文作者设计实验的方式让我回想起，国内研究文章的特点：千篇一律，从一个模子雕出来的
#       1. <b style="color:gray">how do they define criterion?</b>
#    1. keynote:
# 1. <b style="color:#2874A6">Offline Evaluation to Make Decisions About Playlist Recommendation Algorithms</b>
#    1. workind: To
#    1. topics: evaluation method
#    1. que: how to combine goodness of online test and offline test?
#    1. data: private
#    1. contri: a new evaluation method
#    1. review:
#       1. <b style="color:red">very valuable</b>
#       1. IdeaClue: shortage-->que-->model
#          1. shortage:
#             1. online test is good but inefficient
#             1. offline test is efficient but suffers bias
#          1. idea: combine
#       1. a research about method of methods
#    1. keynote: things i don't know and meet the first time
#       1. evaluation method/ <b style="color:gray">statistical test</b>: used to quantify why u report such result?
#          > needs to supplement, i don't know this at all.
#       1. Counterfactual analysis
#       1. metrics category: importance sampling $\rightarrow$ unbiased evaluation
#          1. error-based metrics: MAE, RMSE
#          1. rank-based metrics:
#             1. precision
#             1. recall
#             1. mean-average-precision(MAP)
#             1. normalized discounted cumulative gain(nDCG)
#             1. mean reciprocal rank(MRR)
# 1. <b style="color:#2874A6">When People Change their Mind: Off-Policy Evaluation in Non-stationary Recommendation Environments</b>
#    1. workind: To
#    1. topics: evaluation method
#    1. que: non-stationary off-policy evaluation
#    1. data
#       1. lastFM
#       1. Delicious
#    1. contri
#       1. propose off-policy estimators under 2 moving average
#       1. provide a rigorous analysis of the proposed estimators’ bias in the non-stationary setting
#    1. review
#       1. <b style="color:red">valuable</b>
#       1. IdeaClue: shortage-->que-->model
#    1. connection:
#       1. ref: Offline Evaluation to Make Decisions About Playlist Recommendation Algorithms
#       1. RL
#    1. keynote:
#       1. recommendation $vs$ advertising
#       1. off-policy：<b style="color:gray">use historical
#          interaction data, often referred to as bandit feedback, collected by
#          an existing logging policy to estimate the performance of a new
#          policy.</b>
#       1. contextual bandit framework: <b style="color:gray">an interactive
#          system(e.g., a recsys), often called a <b style="color:gold">policy</b>, observes
#          a <b style="color:gold">context</b>(e.g., a user visiting a website), performs
#          an <b style="color:gold">action</b>(e.g.,
#          by showing a recommendation to the user) and finally observes a
#          <b style="color:gold">reward</b> for the performed action</b>
#       1. inverse Propensity Scoring(IPS)
# 1. <b style="color:#2874A6">Top-K Off-Policy Correction for a REINFORCE Recommender System</b>
#    1. workind: Ao
#    1. topics: RL-based RecSys
#       1. <b style="color:gray">Why RL applied?</b>
#    1. ideaclue: combination/exploration new method to new application
#    1. que: how to explore RL frame into RecSys environment?
#       1. multi-output in RecSys, but one output in RL
#       1. very large state/action space
#       1. no explicit reward, thus hard to explore by self-play
#    1. data: simulation + private
#    1. contri
#       1. product scalability
#       1. propose new off-policy correction method
#       1. applying off-policy correction to address biase
#       1. the value of exploration
#    1. connection
#    1. review
#       1. why use RL in RecSys?
#          1. optimal long-term reward: RL is good at mining optimal result by exploration
#          1. offers a new viewpoint to see recommendation：
#    1. keynote
#       1. offline bias: log are recommended by previous RecSys
#       1. state1: users' shifting interest
#       1. RecSys works in 2 way:
#          1. sort
#          1. find
#       1. RL: building agents that take actions in an environment so as
#          to maximize some notion of <b style="color:gold">long term reward</b>.
# 1. <b style="color:#2874A6">Investment Recommendation System for Low-Liquidity Online Peer to Peer Lending (P2PL) Marketplaces</b>
#    1. workind: Ao; non-traditional
#    1. keynote:
#       1. P2PL: peer-to-peer lending
# 1. <b style="color:#2874A6">Shaping Feedback Data in Recommender Systems with Interventions Based on Information Foraging Theory.</b> Cornell
#    1. workind: To/CDo; non-traditional
#    1. topics:
#    1. que: purely algorithmic approach is myopic for optimizing learning effectiveness
#       1. RecSys'goal is to make accurate and personalized predictions that match a user's preferences
#       1. previous work improves accuracy purely from an algorithmic standpoint:
#          by equipping the learning algorithms with more powerful generalization
#          mechanisms such as deep learning
#          1. gains are small
#          1. theoretical limits
#          1. ignore the feedback process
#    1. contri:
#       1. present the concept of foraging interventions for optimizing
#          implicit feedback generation in recommender systems.
#       1. assess implicit feedback data along two dimensions: quality, quantity
#    1. ideaclue: shortage-->que-->model
#       1. shortage: pure algorithmic way is myopic
#       1. clue:
#          1. much of ML's effectivness comes from feedback data
#          1. deliberately shape the implicit feedback data generated
#             through the design of the user interface.
#    1. review:
#       1. good story
#       1. This kind of work(user study), its paper structure is quite different.
#          * Ref:
#            1. Offline Evaluation to Make Decisions About Playlist Recommendation Algorithms
#            1. When People Change their Mind: Off-Policy Evaluation in Non-stationary Recommendation Environments
#    1. keynote:
#       1. information foraging theory: describe how people seek information in unknown environments
#       1. Figure1: high-level structure of a typical recommender system
# 1. <b style="color:#2874A6">Session-Based Social Recommendation via Dynamic Graph Attention Networks</b>
#    1. workind: Ao
#    1. topics: SBR, SocR, GNs
#    1. ideaclue: model-->story
#       1. model: dynamics + GNs
#       1. story: dynamic + structure
#    1. que: how to model dynamic nature of social networks in RecSys?
#       1. assumption: user's interest depends on both her recent behaviors and social influences
#       1. user interest are dynamics <b style="color:gray">$\Longrightarrow$ dynamic. (node? edge? CWA/OWA?)</b>
#       1. users in online communities are influenced by each other <b style="color:gray">$\Longrightarrow$ structure</b>
#    1. data:
#       1. douban
#       1. delicious
#       1. yelp
#    1. review:
#       1. <b style="color:red">valuable</b>
#       1. very good story: dynamic + social
#          1. dynamics = long-term interest + short-term interest
#             1. long-term = intra-session
#             1. short-term = inner-session
#             1. dynamic:
#                1. target users:
#                   1. intra-session has different interest
#                   1. intra-session uses different links <b style="color:gray">$\Longrightarrow$ different $N(u)$</b>
#                   1. intra-session uses different aspect: <b style="color:gray">$\Longrightarrow$
#                      different neighbor embedding $s_k$, modeling different aspects(long-term or short-term)
#                      of the same node at different session</b>
#          1. social = link structure = influence
#             1. node: user interest = $\sigma$($\mathbf{W}$[long-term interest, short-term interes])
#             1. edge:
#                1. inner-session = one set of edges
#                1. intra-session = different set of edges = different long-term interests of neighbors used
#     1. keynote:
#        1. session-based recommendation
# 1. <b style="color:#2874A6">Recurrent Recommendation with Local Coherence</b>
#    1. workind: Ao
#    1. topics: SeqR, dynamic
#    1. que: how to balance sequency evoluation with local coherent
#    1. review:
#       1. ideaclue: shortage-->que-->model
#          1. shortage: previous work cannot deal with user and item dynamics evolution at same time
#             with local coherent
#          1. model: RRLC
#             1. design a sequence-based embedding approach to capture
#                * local coherence for user/item
#                * rating from both explicit/implicit feedback sequences
#             1. capture the evolution of users and items with parallel RNNs
#             1. integrate coherence-enhanced consistent latent factors and dynamic latent factors
#    1. keynote:
#       1. dynamic evoluation: long-term trends
#       1. local coherrent: short-term similarity
# 1. <b style="color:#2874A6">Taxonomy-Aware Multi-Hop Reasoning Networks for Sequential Recommendation</b>
#    1. workind: Ao
#    1. topics: SeqR, taxonomy data
#    1. que:
#       1. shortage of existing method:
#          1. use one single vectorized representation for learning the overall sequential characteristics
#             <b style="color:gray">$\longrightarrow$ limited modeling power</b>
#          1. directly take feature vectors from context data as auxiliary input.
#             <b style="color:gray">$\longrightarrow$ difficult to exploit the structural patterns</b>
#    1. data:
#       1. last.fm
#       1. jd: private
#       1. amazon music
#    1. contri: use taxonomy data as side information
#    1. review:
#       1. ideaclue: model-->story
#    1. keynote:
#       1. sequential recommendation: predict successive items given previous interaction records
# 1. <b style="color:#2874A6">A Simple Convolutional Generative Network for Next Item Recommendation</b>
# 1. <b style="color:#2874A6">Solving the Sparsity Problem in Recommendations via Cross-Domain
#     Item Embedding Based on Co-Clustering</b>
# 1. <b style="color:#2874A6">NAIRS: A Neural Attentive Interpretable Recommendation System</b>
# 1. <b style="color:#2874A6">Preference Elicitation Strategy for Conversational Recommender System</b>
# 1. <b style="color:#2874A6">Deep Learning for Matching in Search and Recommendation.</b>
