# %% [markdown]
# ## AAAI2019
# ---
# 1. [Discrete Social Recommendation](https://www.aaai.org/Papers/AAAI/2019/AAAI-LiuC.2795.pdf).
# Chenghao Liu (Singapore Management University)*; Xin Wang (Tsinghua University); Tao Lu (Zhejiang University); Wenwu Zhu (Tsinghua University); Jianling Sun (Zhejiang University); Steven Hoi (SMU).
# 1. [Non-Compensatory Psychological Models for Recommender Systems]().
# Chen Lin (Xiamen University), Xiaolin Shen (Xiamen University), Si Chen (Xiamen University), Muhua Zhu (Alibaba Group), Yanghua Xiao (Fudan University).
# > Interesting part: non-compensatory mechenism <br>
# > <img src="img/non_compensatory.png" height="30%" width="30%">
# 1. Dynamic Explainable Recommendation based on Neural Attentive Models.
# Xu Chen (Tsinghua University),Yongfeng Zhang (Rutgers University), Zheng Qin (Tsinghua University).
# > Dynamic + explainable(what + who + when) <br>
# > user preference dynamic change + explanation <br>
# > <img src="img/der.png" height="50%" width="50%">
# 1. GAMENet: Graph Augmented MEmory Networks for Recommending Medication Combination.
# Junyuan Shang (Peking University); Cao Xiao (IBM Research )*; Tengfei Ma (IBM Research); Hongyan Li (Peking University); Jimeng Sun (CS).
# > longitudinal patient history(Dual-RNN) + adverse drug-drug interaction(GCN) <br>
# > Medication combination recommendation <br>
# > <img src="img/GAMENet.png" height="60%" width="60%">
# 1. DAN : Deep Attention Neural Network for News Recommendation.
# Qiannan Zhu, Xiaofei Zhou, Zeliang Song, Jianlong Tan, Li Guo.
# > News recommendation: news profile(paralleling CNN: profile+tittle) + user click history(attention RNN) <br>
# > <img src="img/DAN.png" height="60%" width="60%">
# 1. **From Zero-Shot Learning to Cold-Start Recommendation**.
# Jingjing Li; Mengmeng Jing; Ke Lu; Yang Yang; Zi Huang.
# > Reveal the connection between CSR and ZSL: use ZSL model(LLAE) to solve cold start recommendation <br>
# > <img src="img/zsl2csr.png" width="30%" height="30%">
# 1. **Joint Representation Learning for Multi-Modal Transportation Recommendation**.
# Hao LIU (Business Intelligence Lab, Baidu Research)*; Ting Li (School of Computer Science, National University of Defense Technology, Changsha, China); Renjun Hu (Beihang University); Yanjie Fu (Missouri University of Science and Technology); Hui Xiong (Rutgers University); Jingjing Gu (Nanjing University of Aeronautics and Astronautics)
# > Transportation mode recommendation: given a user and an Origin-Destination pair, how to effectively
#   identify the most appropriate transport mode.
# > word embedding + network embedding --> representation learning. <br>
# > <img src="img/tran2vec.png" width="30%" height="30%">
# 1. **Deeply Fusing Reviews and Contents for Cold Start Users in Cross-Domain Recommendation System**.
# Wenjing Fu, Zhaohui Peng, Senzhang Wang, yang xu , Jin Li.
# > **MISSED**
# 1. **Large-scale Interactive Recommendation with Tree-structured Policy Gradient**.
# Haokun Chen (Shanghai Jiao Tong University)*; Xinyi Dai (Shanghai Jiao Tong University); Weinan Zhang (Apex Data & Knowledge Management Lab, Shanghai Jiao Tong University); Han Cai (Shanghai Jiao Tong University); Xuejian Wang (Shanghai Jiao Tong University); Ruiming Tang (Noah's Ark Research Lab, Huawei); Yuzhou Zhang (Noah's Ark Research Lab, Huawei); Yong Yu (Shanghai Jiao Tong University)
# > RL-based interactive recommender systems with both efficiency and effectiveness
# 1. **CAMO: A Collaborative Ranking Method for Content Based Recommendation**.
# chengwei Wang (Zhejiang University)*; tengfei Zhou (Zhejiang University); Chen Chen (Zhejiang University); Tianlei Hu (Zhejiang University); Gang Chen (Zhejiang University)
# > **MISSED**
# 1. **Holographic Factorization Machines for Recommendation**.
# Yi Tay (Nanyang Technological University)*; SHUAI ZHANG (University of New South Wales); Anh Tuan Luu (Institute for Infocomm Research); Siu Cheung Hui (Nanyang Technological University); Lina Yao (UNSW); Vinh Dang Quang Tran (Nanyang Technological University, Singapore)
# > Enhance Factorization Machines by replacing inner product with holographic reduced representations
# 1. **Multi-order Attentive Ranking Model for Sequential Recommendation**.
# lu yu (King Abdullah University of Science and Technology)*; Chuxu Zhang (University of Notre Dame); Shangsong Liang (Sun Yat-sen University); Xiangliang Zhang (" King Abdullah University of Science and Technology, Saudi Arabia")
# > individual-level item-item transition + union-lvel items-item transition --> predict next item to click <br>
# > multi-order attention network + residual NN.
# 1. [**From Recommendation Systems to Facility Location Games**](https://arxiv.org/pdf/1809.02931.pdf).
# Omer Ben-Porat (Technion – Israel Institute of Technology)*; Gregory Goren (Technion – Israel Institute of Technology); Moshe Tennenholtz (Technion – Israel Institute of Technology); Itay Rosenberg (Technion)
# > Recommender using Game Theory: <span style="color:yellow">totally dont understand a single word</span>
# 1. [**DeepCF: A Unified Framework of Representation Learning and Matching Function Learning in Recommender System**](https://arxiv.org/pdf/1901.04704.pdf).
# Zhihong Deng (Sun Yat-sen University); Ling Huang (Sun Yat-sen University); Chang-Dong Wang
# (Sun Yat-sen University)*; Jian-Huang Lai (Sun Yat-sen University); Philip S Yu (UIC)
#     1. [official implementation](https://github.com/familyld/DeepCF) <br>
# > "One is based on representation learning and the other one is based on matching function learning. To overcome the shortages of these two types of methods and further improve the performance of CF methods, we incorporate them under the proposed DeepCF framework."
# 1. [**Hashtag Recommendation for Photo Sharing Services**](https://pdfs.semanticscholar.org/bdc7/cce0393d1788f992c2e6a824b066e95e15d1.pdf).
# Suwei Zhang (Nanjing University)*; Yuan Yao (Nanjing University); Feng Xu (Nanjing University);
# Hanghang Tong (Arizona State University); Xiaohui Yan (Huawei Technologies); Jian Lv (Nanjing
# University)
# > image-text interaction modeling + user tag habbit modeling --> hashtag recommendation
# 1. [**HERS: Modeling Influential Contexts with Heterogeneous Relations for Sparse and Cold start Recommendation**](https://www.aaai.org/Papers/AAAI/2019/AAAI-HuLiang.4976.pdf). [GitHub](https://github.com/rainmilk/aaai19hers)
# Liang Hu (University of Technology, Sydney)*; Songlei Jian (University of Technology, Sydney);
# Longbing Cao (University of Technology Sydney); Qingkui Chen (University of Shanghai for
# Science and Technology); Zhiping Gu (STIEI); Artak Amirbekyan (Commonwealth Bank)
# > social recommandation: combine user-user, item-item, and user-item impact <br>
# > <img src="img/hers.png" width="40%" height="40%">
# 1. [**An Integral Tag Recommendation Model for Textual Content**](http://cs.nju.edu.cn/yuanyao/static/aaai2019b.pdf).[GitHub](https://github.com/SoftWiser-group/iTag)
# Shi jie Tang (Nanjing University)*; Yuan Yao (Nanjing University); Suwei Zhang (Nanjing
# University); Feng Xu (Nanjing University); Tian xiao Gu (University of California, Davis);
# Hanghang Tong (Arizona State University); Xiaohui Yan (Huawei Technologies); Jian Lv (Nanjing
# University)
# > tag recommendation considering: sequential text modeling + tag correlation + content-tag overlapping <br>
# > <img src="img/itag.png" width="40%" height="40%">
# 1. [**Where to Go Next: A Spatio-Temporal Gated Network for Next POI Recommendation**](https://www.aaai.org/Papers/AAAI/2019/AAAI-ZhaoP.5172.pdf).
# Pengpeng Zhao (Soochow University)*; Haifeng Zhu (Soochow University); Yanchi Liu (Rutgers
# University); Jiajie Xu (Soochow University); Zhixu Li (Soochow University); Fuzhen Zhuang
# (Institute of Computing Technology, Chinese Academy of Sciences); Victor S. Sheng (University
# of Central Arkansas); Xiaofang Zhou (University of Queensland)
# > next POI Recommendation considering both time intervals and geographical distances
# 1. [**Explainable Recommendation Through Attentive Multi-View Learning**](https://www.microsoft.com/en-us/research/uploads/prod/2018/10/exrec-aaai-camera-ready.pdf).
# Jingyue Gao (Peking University)*; Xiting Wang (Microsoft Research Asia); Yasha Wang (Peking
# University); Xing Xie (Microsoft Research Asia)
# > alleviate the trade-off between accuracy and explainability: deep + explainable <br>
# > <img src="img/DEAML.png" width="50%" height="50%">
# 1. [**Reasoning over Knowledge Graph Paths for Recommendation**](https://arxiv.org/pdf/1811.04540.pdf).[GitHub](https://github.com/eBay/KPRN)
# Xiang Wang (National University of Singapore)*; Dingxian Wang (Ebay); Canran Xu (Ebay);
# Xiangnan He (National University of Singapore; University of Science and Technology of China);
# Yixin Cao (NUS); Tat-Seng Chua (National university of Singapore)
# 1. [**Session-based Recommendation with Graph Neural Network**](https://arxiv.org/pdf/1811.00855.pdf).
# Shu Wu (NLPR, China); Yuyuan TANG (University of Science & Technology Beijing); Yanqiao ZHU
# (Tongji University)*; Liang Wang (NLPR, China); Xing Xie (Microsoft Research Asia); Tieniu Tan
# (NLPR, China)
# > <img src="img/sr_gnn.png" width="70%" height="70%">
# 1. [**Hierarchical Reinforcement Learning for Course Recommendation in MOOCs**](https://xiaojingzi.github.io/publications/AAAI19-zhang-et-al-HRL.pdf).
# Jing Zhang (Renmin University of China)*; Bowen Hao (Renmin University of China); Bo Chen
# (Renmin University of China); Cuiping Li (Renmin University of China); Hong Chen (" Renmin
# University, China"); Jimeng Sun (CS)
# > remove the courses with few contributions in a prediction as much as possible <br>
# > <img src="img/rl_mooc.png" width="40%" height="40%">
# 1. [**RepeatNet: A Repeat Aware Neural Recommendation Machine for Session-based Recommendation**](https://staff.fnwi.uva.nl/m.derijke/wp-content/papercite-data/pdf/ren-repeatnet-2019.pdf). [Github](https://github.com/PengjieRen/RepeatNet)
# Pengjie Ren (University of Amsterdam)*; Zhumin Chen (Shandong University); Jing Li (Shandong
# University); Zhaochun Ren (JD.com); Jun Ma (Shandong University); Maarten de Rijke
# (University of Amsterdam)
# > Que: repeat consumption + session-based recommendations. <br>
# > An effective neural approach decides when to perform repeat recommendation.<br>
# > <img src="img/RepeatNet.png" width="60%" height="60%"> <br>
# 1. [**Evaluating Recommender System Stability with Influence-Guided Fuzzing**](https://www.comp.nus.edu.sg/~david/Publications/aaai2019-preprint.pdf). [poster](http://davidshriver.me/assets/posters/AAAI19-ShriverD.6229.poster.pdf)
# David Shriver (University of Virginia)*; Sebastian Elbaum (University of Virginia); Matthew
# Dwyer (University of Virginia); David Rosenblum (National University of Singapore)
# > test RecSys stability: one dimension of robustness
# 1. [**Hierarchical Context enabled Recurrent Neural Network for Recommendation**](https://ssl.pstatic.net/static/clova/service/clova_ai/research/publications/Hierarchical.Context.enabled.Recurrent.Neural.Network.for.Recommendation.pdf).
# Kyungwoo Song (KAIST); Mingi Ji (KAIST); Sungrae Park (KAIST); Il-Chul Moon (KAIST)*
# > user history capturing: global long-term + local short-term + temporary term
