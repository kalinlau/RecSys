# %% [markdown]
# # [WWW19](https://www2019.thewebconf.org/proceedings-html.html)
# ---
# 1. [Variational Session-based Recommendation Using Normalizing Flows](https://dl.acm.org/authorize.cfm?key=N673762). Fan Zhou (University of Science and Technology of China, China); Zijing Wen (University of Science and Technology of China, China); Kunpeng Zhang (University of Maryland, United States); Goce Trajcevski (Iowa State University, United States); Ting Zhong (University of Science and Technology of China, China)
#     1. que:
#         1. taxonomy: session-based recommendation(SBR)
#         1. specific: try to imply generative like VAE into RecSys
#     1. data
#         1. yoochoose 1/64
#         1. yoochoose 1/4
#     1. sums
#         1. typical application-directed research; try to apply generative method into RecSys
#         1. Bayesian models like VAE(?) cannot be directly applied due to:
#             > <b style="color:gold">but this are not specific to RecSys domain, any VAE's application needs to face</b>
#
#             1. data availability
#             1. Bypassing issue(?)
#             1. biased prior
#         1. Why to apply? What advantage does it have?
#         1. what is VAE?
# 1. [Improving Top-k Recommendation via Joint Collaborative Autoencoders](https://dl.acm.org/authorize.cfm?key=N673763). Ziwei Zhu (Texas A&M University, United States); Jianling Wang (Texas A&M University, United States); James Caverlee (Texas A&M University, United States) <b style="color:red">[valuable]</b>
#     1. que:
#         1. taxonomy: 3 graph view
#         1. specific: join user-user and item-item correlation/relation together
#     1. tech: autoencoder
#     1. data
#         1. MovieLen-1M
#         1. Yelp
#         1. Amazon Video Games
#     1. sum
#         1. use generative model to join user-user and item-item correlation. This could be a baseline and heuristic
#            clue to graph-base user-user and item-item relation
#         1. Can all of the 3 relations be joint together: user-user, user-item, item-item, and why to do this?
# 1. [A Scalable Hybrid Research Paper Recommender Platform for Microsoft Academic](https://dl.acm.org/authorize.cfm?key=N673542). Anshul Kanakia (Microsoft, United States); Zhihong Shen (Microsoft, United States); Darrin Eide (Microsoft, United States); Kuansan Wang (Microsoft, United States) <b style="color:red">[valuable]</b>
#     1. que
#         1. taxonomy: hybrid system
#         1. specific:
#             1. several dilimma:
#                 1. cross-domain is limited
#                 1. CF-based method --> cold start
#                 1. General Data Protection Regulation act (GDPR) --> difficult and costly to rely on user data
#                 1. large scale
#     1. tech: hybrid = content-based(CB) + co-citation-based(CcB)
#     1. data: evaluated by online survey
#         1. Microsoft Academic Graph: opensource
#     1. sums
#         1. CcB-based RecSys
#         1. how they evaluate in online survey
#         1. opensource: code and MAG
#         1. a good story: novice researcher finding papers, we integrate RecSys
#         1. a good background and introduction for RecSys. This work has been applied to Microsoft Academic
# 1. [With a little help from my friends (and their friends): Influence neighborhoods for social recommendations](https://dl.acm.org/authorize.cfm?key=N673510). Avni Gulati (San Jose State University, United States); Magdalini Eirinaki (San Jose State University, United States)
#     1. que:
#         1. taxonomy: social recommender
#         1. specific:
#             1. influence propagation
#             1. node direct neighbor $\rightarrow$ graph-based neighbor
#     1. idea: graph-based neighborhood preprocess + MF
#     1. tech
#     1. data:
#         1. Yelp
#         1. Epinions
# 1. [User-Video Co-Attention Network for Personalized Micro-video Recommendation](https://dl.acm.org/authorize.cfm?key=N673686). Shang Liu (Wuhan University, China); Zhenzhong Chen (Wuhan University, China); Hongyi Liu (Amazon, United States); Xinghai Hu (Facebook, United States)
#     1. que: micro-video recommendation
#         * not only users have multi-modal interest, but also micro-videos have multi-modal targeted audience
#     1. method: co-attention mechanism
#     1. data: privacy(crawled from website)
# 1. [Context-Aware Sequential Recommendations with Stacked Recurrent Neural Networks](https://dl.acm.org/authorize.cfm?key=N673628). Lakshmanan Rakkappan (National University of Singapore, Singapore); Vaibhav Rajan (National University of Singapore, Singapore)
#     1. que: side info = sequential behavior + context
#         1. context:
#             1. temporal context: repeat consumption gap
#             1. input context: the time break points.
#         1. sequential behavior: u-i interaction ranked according to time order
#     1. data:
#         1. movielens-1m
#         1. amazon books
#     1. sums:
#         1. explicitly model context-aware and sequential info together, not hidden into the RNN models
# 1. [Recommender Systems with Heterogeneous Side Information](https://dl.acm.org/authorize.cfm?key=N673688). Tianqiao Liu (TAL AI Lab, China); Zhiwei Wang (Michigan State University, United States); Jiliang Tang (Michigan State University, United States); Songfan Yang (TAL AI Lab, China); Zitao Liu (TAL AI Lab, China). <b style="color:red">[valuable]</b>
#     1. que: heterogeneous = flat + hierarchical
#     1. data:
#         1. movieLen-1m
#         1. bookcrossing
#     1. sum:
#         1. different maybe even nonsense viewpoint of old things, this gives a hint of how to making story about
#            your work design, which actually comes from trivals but finally seems like some big thing
#         1. <span style="color:gold">flat + hierarchy = graph: then why not use this viewpoint?</span>
#            > this also spans my previous schema idea that graph should be more connected and get deep and wide
# 1. [Hierarchical Neural Variational Model for Personalized Sequential Recommendation](https://dl.acm.org/authorize?N673758).<b style="color:red">[valuable]</b> Teng Xiao (Sun Yat-sen University, China); Shangsong Liang (Sun Yat-sen University, China); Zaiqiao Meng (Sun Yat-sen University, China)
#     1. que:
#         1. taxonomy: personalized sequential recommendation
#         1. capture both short-term and long-term interest
#     1. method: models users’ 3 preferences: through an unified hierarchical deep generative process
#         1. general: <b style="color:GOLD">profile</b>
#             > <b style="color:red">this could be used to user-end KG?</b>
#             > <b style="color:green">No, this will be used in initial embedding</b>
#         1. long-term: past session behavior
#         1. short-term: most recent actions
#     1. data:
#         1. IJCAI-15: <b style="color:red">[not found]</b>
#         1. RecSys challenge 2016: <b style="color:red">[not found]</b>
#     1. sums:
#         1. viewpoint of general, long-term and short-term is interesting and reasonable
# 1. [Adversarial Point-of-Interest Recommendation](https://dl.acm.org/authorize.cfm?key=N673760). Fan Zhou (University of Science and Technology of China, China); Ruiyang Yin (University of Science and Technology of China, China); Kunpeng Zhang (University of Maryland, United States); Goce Trajcevski (Iowa State University, United States); Ting Zhong (University of Science and Technology of China, China); Jin Wu (University of Science and Technology of China, China). <b style="color:red">[valuable]</b>
#     1. que:
#         1. taxonomy: POI
#         1. existing studies lack formal underlying mechanisms to understand essential user check-in behavior
#     1. data:
#         1. Foursquare
#         1. Gowalla
#         1. Yelp
#     1. method: GAN framework
#         1. generator: recommender(R)
#         1. discriminator(D)
#         1. reward: borrowed from RL
#     1. sums:
#         1. this work's real value lies in this fact: it actually merge GAN into RecSys, and for doing so, the
#            authors made a story about so-called "underling user check-in behavior distribution"
#         1. borrows ideas from <b style="color:GOLD">RL</b> to define $reward$
#         1. data released and baselines are borrowed from an official evaluation
#            website for [LBSN](http://spatialkeyword.sce.ntu.edu.sg/eval-vldb17/)
# 1. [Recurrent Convolutional Neural Network for Sequential Recommendation](https://dl.acm.org/authorize.cfm?key=N673751). Chengfeng Xu (Soochow University, China); Pengpeng Zhao (Soochow University, China); Yanchi Liu (Rutgers University, United States); Jiajie Xu (Soochow University, China); Victor Sheng (University of Central Arkansas, United States); Zhiming Cui (Suzhou University of Science and Technology, China); Xiaofang Zhou (University of Queensland, Australia); Hui Xiong (State University of New Jersey, United States)
#     1. que: sequential recommendation = long range(LSTM) + short range(CNN on hidden state of LSTM)
#         1. taxonomy: POI
#         1. non-linear feature interactions --> horizontal CNN filter
#         1. non-monotone short-term sequential patterns --> vertical CNN filter
#     1. dataset:
#         1. user-POI check-ins information in the location-based social networking sites(LBSN)
#             1. [Gowalla](http://snap.stanford.edu/data/loc-gowalla.html)
#             1. [Foursquare](https://sites.google.com/site/yangdingqi)
#         1. Taobao[ijcai 2017]: <b style="color:red">[not found]</b>
#     1. ref:
#         1. Towards Neural Mixture Recommender for Long Range Dependent User Sequences
# 1. [Click Feedback-Aware Query Recommendation Using Adversarial Examples](https://dl.acm.org/authorize.cfm?key=N673664). Ruirui Li (University of California Los Angeles, United States); Liangda Li (Yahoo Research and Oath, United States); Xian Wu (University of Notre Dame, United States); Yunhong Zhou (Yahoo Research and Oath, United States); Wei Wang (University of California Los Angeles, United States). <b style="color:red">[valuable]</b>
#     1. que: query suggestion in search engine
#         1. why query suggestion?
#             1. untrained users with unclearly expressed intention
#             1. hard to transform user intent into limited keywords
#     1. data: self-collection and not published
#     1. sums:
#         1. add adversial samples to improve rebustness
#         1. add feedback info to improve feedback-awareness
# 1. [Knowledge Graph Convolutional Networks for Recommender Systems](https://C/User/liujialin/Document/phd/papers). Hongwei Wang (Shanghai Jiao Tong University, China); Miao Zhao (Hong Kong Polytechnic University, Hong Kong); Xing Xie (Microsoft, China); Wenjie Li (Hong Kong Polytechnic University, Hong Kong); Minyi Guo (Shanghai Jiao Tong University, China). <b style="color:red">[valuable]</b>
#     1. que: CF: cold start/data sparsity --> side information --> KG
#     1. data:
#         1. items: movieLen, lastFM
#         1. KG: microsoft satori(private)
#     1. refs:
#         1. Hongwei Wang KDD2019. KGCN-LS
# 1. [Collaborative Similarity Embedding for Recommender Systems](https://dl.acm.org/authorize.cfm?key=N673570). Chih-Ming Chen (National Chengchi University and Academia Sinica, Taiwan); Chuan-Ju Wang (Academia Sinica, Taiwan); Ming-Feng Tsai (National Chengchi University, Taiwan); Yi-Hsuan Yang (Academia Sinica, Taiwan). <b style="color:red">[valuable]</b>
#     1. que: generalize similarity measure of multi-type relations within u-i bipartitle graph
#         1. 1-hop or higher order
#         1. u-u, i-i similarity from u-i
#     1. data: 8 public
#     1. method:
#         1. similarity embedding module
#             1. direct similarity: u-i
#             1. neighborhood similarity: u-u, i-i
#         1. triplet embedding: ideally model user-user, item-item clustering and user-item
#            relations in a single and joint-learning model
#         1. sampling method: fuse similarity module and triplet module
#     1. sums:
#         1. <span style="color:red;">inner info of u-i bipartite graph use ratio improvance,
#            side information like social network is like intra info use introduced.</span>
#                1. how to judge use ratio of inner u-i and intra u-u social graph, i-i graph using information theory
#         1. unify two streams of work: traditional model-based or neighbor-based CF, use u-u or i-i similarity apart as
#            weights in u-i interaction rates. this work unify them into one single frame: u-u or i-i similarity learnt
#            from direct similarity embedding model
#         1. strong baseline and work release on [Github](https://github.com/cnclabs/smore.git)
# 1. [Pcard: Personalized Restaurants Recommendation from Card Payment Transaction Records](https://dl.acm.org/authorize.cfm?key=N673584). Min Du (University of California Berkeley, United States); Robert Christensen (Visa Research, United States); Wei Zhang (Visa Research, United States); Feifei Li (University of Utah, United States)
#     1. que: personalized POI
#         1. taxonomy: POI
#     1. data: private
#     1. sums:
#         1. POI: Point of Interest
#         1. user embedding = user transaction history + location information
#             > the so called "personalized" actually refers to "user embedding"
#         1. this sentence is somehow 没话找话:
#             > traditional personalized recommendation systems typically use collaborative filtering
# 1. [Towards Neural Mixture Recommender for Long Range Dependent User Sequences](https://dl.acm.org/authorize.cfm?key=N672319). Jiaxi Tang (Simon Fraser University, Canada); Francois Belletti (Google, United States); Sagar Jain (Google, United States); Minmin Chen (Google, United States); Alex Beutel (Google, United States); Can Xu (Google, United States); Ed H. Chi (Google, United States). <b style="color:red">[valuable]</b>
#     * Que: different temporial granularity modeling of user preference
#
#         > in another word: right items to users at the right time.
#
#         1. sequential recommender systems
#         1. while different applications and contexts require different temporal
#            ranges and patterns, model architectures are typically designed to
#            capture a particular temporal dynamic. How can we design a model that
#            works, simultaneously, across all of these contexts and temporal ranges?
#     * Relevent:
#         1. Modeling Heart Rate and Activity Data for Personalized Fitness Recommendation
#     * Data:
#         1. MovieLen-20m
#         1. Youtube(private)
#     * Sum:
#         1. simultaneously capture short and long range of user preference is an important research direction
#            just as Hongwei Wang and Xing Xie point out.
#     * further reading que:
#         1. methodology, how they capture different range simultaneously?
#         1. effectiveness, is their model really solve the multi-granularity problem?
# 1. [Unifying Knowledge Graph Learning and Recommendation: Towards a Better Understanding of User Preference](https://dl.acm.org/authorize.cfm?key=N672029). Yixin Cao (National University of Singapore, Singapore); Xiang Wang (National University of Singapore, Singapore); Xiangnan He (National University of Singapore, Singapore); Zikun Hu (National University of Singapore, Singapore); Tat-Seng Chua (National University of Singapore, Singapore). <b style="color:red">[valuable]</b>
#     * Que: KGC + RecSys jointly <span style="background-color:gray; color:YELLOWGREEN">this idea is not sperendipity</span>
#         1. KG may not be complete when applied
#         1. KG could enhance recommender acc
#     * Method: KTUP: transfer <b>relation</b> message into embedding
#     * Data:
#         1. movielen-1m
#         1. DBbook2014
#         1. DBpedia: KG for mapping: $items \rightarrow entities$
#     * Sum:
#     * Rev:
#       1. SamWalker: Social Recommendation with Informative Sampling Strategy
#           > implicit feedback strategy
#
# 1. [Hierarchical Temporal Convolutional Networks for Dynamic Recommender Systems](https://dl.acm.org/authorize.cfm?key=N672498). Jiaxuan You (Stanford University, United States); Yichen Wang (Georgia Institute of Technology, United States); Aditya Pal (Pinterest, United States); Pong Eksombatchai (Pinterest, United States); Chuck Rosenburg (Pinterest, United States); Jure Leskovec (Stanford University, United States)
#     * Que: effective and efficient cross-session recommendation
#         1. RNN-based: slow
#         1. CNN-based: memory cost
#     * Method: HierTCN = TCN + RNN
#     * Data:
#         1. XING(public)
#         1. Pinterest(private)
#     * Sum:
#         1. cross-session is interesting
#         1. use of CNN to improve efficiency is not a new idea
#         1. this paper is valuable at training how to organize your story when
#            yor finish your idea -- a tottom-to-up way
#     * Further Que:
#         1. then why CNN + RNN leads to efficiency(speed) and effectiveness(storage)
# 1. [Value-aware Recommendation based on Reinforced Profit Maximization](https://dl.acm.org/authorize.cfm?key=N673604). Changhua Pei (Alibaba Group, China); Xinru Yang (Carnegie Mellon University, United States); Qing Cui (Alibaba Group, China); Xiao Lin (Alibaba Group, China); Fei Sun (Alibaba Group, China); Peng Jiang (Alibaba Group, China); Wenwu Ou (Alibaba Group, China); Yongfeng Zhang (Rutgers University, United States). <b style="color:red">[valuable]</b><b style="color:green">[RL]</b>
#     * Que: criterion and 2 fundamental tasks not directly conencted to the revenue and profits
#         1. 2 fundamental task: rate prediction, top-k recommendation
#         1. criterion: RMSE, MAP, etc
#         1. what we care is revenue/profit: give me money
#     * idea: balance the unit profit of a recommendation and the chance that the recommendation is purchased.
#         1. click conversion rate(CVR) $\rightarrow$  conversion rate of arbitrary user actions(XVR)
#     * Data:
#         1. self collection, but published
# 1. [Jointly Leveraging Intent and Interaction Signals to Predict User Satisfaction with Slate Recommendations](https://dl.acm.org/authorize.cfm?key=N672227)<b style="color:red">[valuable]</b>. Rishabh Mehrotra (Spotify Research, United Kingdom); Mounia Lalmas (Spotify Research, United Kingdom); Doug Kenney (Spotify, United States); Thomas Lim-Meng (Spotify, United States); Golli Hashemian (Spotify, United States)
#     1. Que: understanding relation among interaction signal, user intent and user satisfaction
#         1. phenomenon: same feedback behavior means different level of SAT under different intention
#         1. explaination:
#             1. interaction --> implicit signal --> not clear in intent as explicit signal
#             1. intent: why they do such thing presented as behavior signal
#             1. user satisfaction
#         1. hypothesize:
#             1. interaction signal without factoring in user intent leads to unreliable estimate of SAT
#             1. user satisfaction conditioned on both recommendation and intent
#     1. How:
#        1. what interaction signal used?
#           1. temporal signal
#           1. surface level signal
#           1. downstream signal
#           1. derivative signal
#        1. how to model user intent?
#           1. identify what kind of user intent: by interviews and post-hoc analysis
#             > 2 groups of 7 kinds
#           1. justify and statistic analysis: by in-app survey and histogram
#           1. ensure indent identified cover the intent space: by Bayesian non-parametric model
#             > non-parametric clustering: used when prior is unknown, in this work, intent cluster
#        1. how to measure user satisfaction level?
#          > as probability to be predicted
#     1. Summary: learn what they do, and how they do it, how they think and design
#       1. the research form used in this paper is valuable:
#           1. find phenomenon and give your hypothesize
#           1. identify and quantify
#           1. validate
#           1. model the phenomenon you find into your application field
#       1. the useage of non-parametric clustering
#       1. How they design their research procedure is valuable
#           1. how to model abstract concept like intent?(interview, survey, statistics validation)
#              1. find number of kinds: interview, survey
#              1. validate the number of kinds coverd: statistic inference
#           1. how to model your target like SAT
#              1. use probability
# 1. [Improving Outfit Recommendation with Co-supervision of Fashion Generation](https://dl.acm.org/authorize.cfm?key=N672299). Yujie Lin (Shandong University, China); Pengjie Ren (University of Amsterdam, Netherlands); Zhumin Chen (Shandong University, China); Zhaochun Ren (JD.com, China); Jun Ma (Shandong University, China); Maarten de Rijke (University of Amsterdam, Netherlands)
#     1. Que: outfit recommendation
#        1. scene: given top(or bottom) fit and a sentence dscribes what bottom(top) is wanted, recommend them
#        1. fashion  = visual understanding + visual matching
#           1. visual understanding: img <-- concept(sentence)
#           1. visual matching: img --> concept
#     1. sum:
#        1. fashion style in reality is actually something you don't know as prior, it's more like a 选择题 rather
#           than 填空题 or 简答题
#           > and this kind of recommendation, formed as sperendity, is what i think important, and naturally it
#             matches the long-tail phenomenon
#        1. Though the specific question of outfit recommendation they try to solve is trial, this clue may shed
#           some light upon how you give your model or experiment result a good story. A better and deeper research
#           after this, is that allievate the condition and go on with sperendipity.
# 1. [Policy Gradients for Contextual Recommendations](https://dl.acm.org/authorize.cfm?key=N672357). Feiyang Pan (Chinese Academy of Sciences, China); Qingpeng Cai (Tsinghua University, China); Pingzhong Tang (Tsinghua University, China); Fuzhen Zhuang (Chinese Academy of Sciences, China); Qing He (Chinese Academy of Sciences, China). <b style="color:red">[valuable]</b><b style="color:green">[RL]</b>
#     1. Que: policy gradient reinforcement learning for context-aware recommendations
#        1. trade-off between exploration and exploitation
#           1. policy-based
#           1. new realistic contextual-bandit
#           1. new realistic reward function
#     1. Method: property of Greedy in the Limit with Infinite Exploration
#     1. summary:
#        1. reinforcement learning based recommender, maybe connected to GNs frame
# 1. [Modeling Heart Rate and Activity Data for Personalized Fitness Recommendation](https://dl.acm.org/authorize.cfm?key=N672233). Jianmo Ni (University of California San Diego, United States); Larry Muhlstein (University of California San Diego, United States); Julian McAuley (University of California San Diego, United States)
#     1. Que: predict heterogeneous dynamics of working profile and recommendation
#        1. route recommendation
#        1. heart rate prediction
#     1. Sum: this paper is actually dealing with sequential data dynamics modeling, what it calls recommendation
#        is probability conditioned on certain criteria (prescribed by workout time, idiosyncratic rate and speed
#        curve, etc.)
# 1. [DKN: Deep Knowledge-Aware Network for News Recommendation](https://arxiv.org/abs/1801.08284). Hongwei Wang, Fuzheng Zhang, Xing Xie, Minyi Guo. WWW 2018.
# 1. [Multi-Task Feature Learning for Knowledge Graph Enhanced Recommendation](https://arxiv.org/abs/1901.08907). [**Github**](https://github.com/hwwang55/MKR). Hongwei Wang (Shanghai Jiao Tong University, China); Fuzheng Zhang (Meituan-Dianping, China); Miao Zhao (Hong Kong Polytechnic University, Hong Kong); Wenjie Li (Hong Kong Polytechnic University, Hong Kong); Xing Xie (Microsoft, China); Minyi Guo (Shanghai Jiao Tong University, China)
# 1. [Dual Graph Attention Networks for Deep Latent Representation of Multifaceted Social Effects in Recommender System](https://arxiv.org/abs/1903.10433). Qitian Wu (Shanghai Jiao Tong University, China); Hengrui Zhang (Shanghai Jiao Tong University, China); Xiaofeng Gao (Shanghai Jiao Tong University, China); Peng He (Tencent, China); Paul Weng (Shanghai Jiao Tong University, China); Han Gao (Tencent, China); Guihai Chen (Shanghai Jiao Tong University, China). <b style="color:red">[valuable]</b>
# <div style="background-color:gray">
#     data sparsity/cold start --> social info --> static effect formed in constant weight or constaint form(This is not real psychological phenomenon) --> solution: 2-fold(homophily + influence) in 2 domain(user + item) by GAT + jointly model
# </div>
# 1. [GhostLink: Mining Latent Influence Networks for Influence-aware Item Recommendation](https://people.mpi-inf.mpg.de/~smukherjee/research/www19-ghostlink.pdf). Subhabrata Mukherjee (Amazon, United States); Stephan Guennemann (Technical University of Munich, Germany). <b style="color:red">[valuable]</b>
# <div>
#     <ol>
#         <li>given only time-stamped reviews, find out latent influence network: who influence who
#             <div style="color:#F39C12">many online plateform like Amazon, don't have explicit social network</div>
#         </li>
#         <li>use latent inflence network to improve recommendation</li>
#     </ol>
# </div>
# 1. [Signed Distance-based Deep Memory Recommender](https://arxiv.org/abs/1905.00453). Thanh Tran (Worcester Polytechnic Institute, United States); Xinyue Liu (Worcester Polytechnic Institute, United States); Kyumin Lee (Worcester Polytechnic Institute, United States); Xiangnan Kong (Worcester Polytechnic Institute, United States)
#     * Que: user preference modeled as linear combination(eg. MF)
#     * Solution: deep learning framework to capture non-linear relationship between user-item explicitly/implicitly
#       1. explicit: user-item distance;
#          implicit: item-item distance;
#       1. distance measure: leant by
#         1. SDM: target item + recent(user) items
#         1. SDP: user + target item
#         1. soft attention --> recent items
#     * Summary: I don't think this is an interesting idea.
#       1. basically, it is still CF by similarity, what they call distance is just similarity learnt by DNN, among
#          different pairs, like user-item, item-item;
#       1. not as what authors' mentioned, there are other works dealling: item-item graph, not equal contribution.
#       1. if this is some kind of distance, then u need to prove it in mathmetically:
#           d(x)>= 0; |d(x)-d(y)| <= d(x+y) <= d(x)+d(y);
#           $$d(x) \geq 0 \\ \left|d(x) + d(y)\right| \le d(x+y) \leq d(x) + d(y)$$
#       1. as for linear and non-linear relationship, what is the physical or psychological meaning?
# 1. [Multimodal Review Generation for Recommender Systems](https://drive.google.com/file/d/12RSrAxp9O5YPPoazoAu5Frc-c0X4Rtyq/edit). Quoc-Tuan Truong (Singapore Management University, Singapore); Hady Lauw (Singapore Management University, Singapore)
#     1. Que: Given a user and an item, generate both the rating and the review text
#        > why: benifit each other, proved by experiment, and previous
#          work only focus on either one of the two problems
#
#     1. assumption: jointly modeling would benifit both rate prediction and review generation.
#     1. method: join rate prediction by nonlinearity and review text generation by LSTM
#     1. summary:
#        1. what's the physical foundation of joining multi-task lying behind?
# 1. [Beyond Shortest Paths: Route Recommendations for Ride-sharing](https://dl.acm.org/authorize?N672655). Chak Fai Yuen (Indian Institute of Technology Delhi, India); Abhishek Pratap Singh (Indian Institute of Technology Delhi, India); Sagar Goyal (Indian Institute of Technology Delhi, India); Sayan Ranu (Indian Institute of Technology Delhi, India); Amitabha Bagchi (Indian Institute of Technology Delhi, India)
#     1. Que: route recommendation in ride-sharing environments.
#        > Can we move beyond shortest paths by recommending a route that is
#          close in length to the shortest path and offers much higher chance
#          of finding a compatible ride-order?
#
#     1. Method: attack the route recommendation problem
#     1. Sum: question scenerory is quite clear, but method i can't understand well.
# 1. [How Serendipity Improves User Satisfaction with Recommendations? A Large-Scale User Evaluation](https://dl.acm.org/authorize?N671475)<b style="color:red">[very valuable]</b>. Li Chen (Hong Kong Baptist University, Hong Kong); Yonghua Yang (Alibaba Group, China); Ningxia Wang (Hong Kong Baptist University, Hong Kong); Keping Yang (Alibaba Group, China); Quan Yuan (inspirAI, China)
#     * Que: serendipity in recsys
#     * contribution: empirically revealance
#       1. casual relationship of different beyond-accuracy criteris:
#          > novelity/timeliness/relevance/unexpectedness --> serendipity --> satisfaction/purchase intention
#       1. reveal a phenomenon: user curiosity moderate effect to:
#         1. novelty --> serendipity
#         1. serendipity --> satisfaction
#       1. 4 baseline considering different aspect and compared under multi-aspect
#     * Reference:
#         1. Personalizing recommendation diversity based on user personality
# 1. [Exploiting Ratings, Reviews and Relationships for Item Recommendations in Topic Based Social Networks](http://delivery.acm.org/10.1145/3320000/3313473/p995-li.pdf?ip=124.16.131.75&id=3313473&acc=OPEN&key=4D4702B0C3E38B35%2E4D4702B0C3E38B35%2E4D4702B0C3E38B35%2E6D218144511F3437&__acm__=1557794012_9c686dde7f5321997b9fabe294981086). Pengfei Li (Zhejiang University, China); Hua Lu (Aalborg University, Denmark); Gang Zheng (Zhejiang University, China); Qian Zheng (Nanyang Technological University, Singapore); Long Yang (Zhejiang University, China); Gang Pan (Zhejiang University, China)
#     * Que: heterogeneous data source(review, social relationship, rate)
#     * Summary:
#       1. background is really blur, logic not clean, it seems like this kind "no one does this, then i try"
#       1. basic framework is still MF-based CF, improvement lying on subtle latent embedding formation
#       1. statistical inference framework - variational inference: this is the main highlight
#     * Q&A:
#       1. what's the physical meaning of probability distribution extraction, e.g, Poisson, Gamma
#       1. where does user social relation data come from?
# 1. [Graph Neural Networks for Social Recommendation](http://delivery.acm.org/10.1145/3320000/3313488/p417-fan.pdf?ip=124.16.131.75&id=3313488&acc=OPEN&key=4D4702B0C3E38B35%2E4D4702B0C3E38B35%2E4D4702B0C3E38B35%2E6D218144511F3437&__acm__=1557797645_0f39f3c7fd90dfdc775aa7a07a6efd77)<b style="color:red">[very valuable]</b>. Wenqi Fan (City University of Hong Kong, Hong Kong); Yao Ma (Michigan State University, United States); Qing Li (City University of Hong Kong, Hong Kong); Yuan He (JD.com, China); Eric Zhao (JD.com, China); Jiliang Tang (Michigan State University, United States); Dawei Yin (JD.com, China)
#     * Que: 3 specific
#       1. how to integrate user information contained in both u-u and u-i
#       1. how to extract interaction between u and i and opinion of u on i
#       1. how to distinguish social relation with different heteronegeous strength
#         > attention
#     * Model: GraphRec
#     * Summary:
#       1. GraphRec = graph(u-u, u-i) + MLP processing way
#         > this means i-i graph can be fused
#       1. where does user social relation data come from?
#         > Can this be used in KG-way, and then KGCN?
#       1. actually it is still a homogeneous graph, heterogeneity solved by attention
# 1. [Cross-domain Recommendation Without Sharing User-relevant Data](http://delivery.acm.org/10.1145/3320000/3313538/p491-gao.pdf?ip=124.16.131.75&id=3313538&acc=OPENTOC&key=4D4702B0C3E38B35%2E4D4702B0C3E38B35%2E4D4702B0C3E38B35%2E9F04A3A78F7D3B8D&__acm__=1557812912_d37549f172ed6e98cdcca8d1733001a4). Chen Gao (Tsinghua University, China); Xiangning Chen (Tsinghua University, China); Fuli Feng (National University of Singapore, Singapore); Kai Zhao (Tsinghua University, China); Xiangnan He (National University of Singapore, Singapore); Yong Li (Tsinghua University, China); Depeng Jin (Tsinghua University, China)
#     * Que: cross-domain recommendation under user privacy protection
#           > src book --> target book, not book recommendation --> movie recommendation
#           (but maybe this is an important question)
#     * Solution: embedding sharing
#       1. src domain embedding extraction
#       1. embedding transfering
#       1. embedding fusing
#     * challenge
#       1. different embedding dimension among src and target
#       1. unclear semantic meaning
#       1. importance judgement between src and target.
#     * summary:
#       1. what remains behind is the real cross-domain recommendation?
#         > book recommendation --> movie recommendation --> music recommendation
# 1. [How Intention Informed Recommendations Modulate Choices: A Field Study of Spoken Word Content](https://dl.acm.org/authorize?N672486)<b style="color:red">[very valuable]</b>. Longqi Yang (Cornell University, United States); Michael Sobolev (Cornell University, United States); Yu Wang (Himalaya Media, United States); Jenny Chen (City University of New York, United States); Drew Dunne (Cornell University, United States); Christina Tsangouri (Cornell University, United States); Nicola Dell (Cornell University, United States); Mor Naaman (Cornell University, United States); Deborah Estrin (Cornell University, United States)
#     * Que: how intention informed recommendations modulate users’ choices, as compared to intention agnostic systems?
#           1. intention-aware: subscription reflect interest, and recommendation based on subcription
#           1. intention-agnostic: popularity-based recommender like CF
#     * conclusion:
#       1. intention aware recommendations for user onboarding significantly raised the ratio of channel subscription
#          and episode listening that were aligned with users’ topic-wise aspirations
#       1. CF-based recommendations significantly increased the ratio of episode listening to not-subscribed channels
#       1. User satisfaction was jointly affected by the recommendation algorithms used in the two stages
#     * Summary:
#       1. this paper deals with such a big problem, that recommender's result may affect user's intention
# 1. [Personalized Bundle List Recommendation](https://dl.acm.org/authorize.cfm?key=N672003). Jinze Bai (Peking University, China); Chang Zhou (Alibaba Group, China); Junshuai Song (Peking University, China); Xiaoru Qu (Peking University, China); Weiting An (Alibaba Group, China); Zhao Li (Alibaba Group, China); Jun Gao (Peking University, China)
#     * Que: just as title suggest
#       1. personalized: means it recommended according to your history and interest
#       1. bundle list: items that are different parts for a whole task, like knife, sticks, plates for eating
#     * Summary: i don't think this is an interesting idea.
# 1. [SamWalker: Social Recommendation with Informative Sampling Strategy](https://dl.acm.org/authorize?N672033).<b style="color:red">[valuable]</b> Jiawei Chen (Zhejiang University, China); Can Wang (Zhejiang University, China); Sheng Zhou (Zhejiang University, China); Qihao Shi (Zhejiang University, China); Yan Feng (Zhejiang University, China); Chun Chen (Zhejiang University, China)
#     * Que: recommendation in implicit feedback need: confidence, sampling strategy
#       1. explicit feedback is limited, but implicit feedback is redundent
#       1. implicit feedback typically always means positive and lack negative
#       1. negative implicit feedback comes from un-observed (user-item) interaction
#       1. un-observed interaction: unknown or dislike
#         1. previously processed as negative feedback with manually set confidence
#         1. now: automatically set
#           1. confidence
#           1. sampling strategy
#     * Method: [not read]
#       1. clue: use social network as side information to deduce confidence
#     * Dataset:
#       1. Epinions: social connection
#       1. Ciao: social connection
#       1. LastFM: implicit feedback
# 1. [Modeling Item-Specific Temporal Dynamics of Repeat Consumption for Recommender Systems](https://dl.acm.org/authorize.cfm?key=N672343). Chenyang Wang (Tsinghua University, China); Min Zhang (Tsinghua University, China); Weizhi Ma (Tsinghua University, China); Yiqun Liu (Tsinghua University, China); Shaoping Ma (Tsinghua University, China)
#     * Que: temporal dynamics of repeat consumption based
#       1. 2 temporal dynamics have been observed
#         1. short-term
#         1. long-term
#       1. item repeat consumption influenced by both long and short, but under different ratios
#       1. system need consider temporal dynamics when recommending
#     * Method: CF + Hawkes Process
#       1. CF model user preference and item similarity into same semantic space
#         > closer means more similar and higher preference
#       1. Hawkes models different temporal dynamics of items
#     * Summary:
#       1. New scenario:
#         1. climate disaster --> rice reduction --> need to store it before there is nothing left
#         1. political change --> news --> product storage&price change --> preorder recommendation
# 1. [Jointly Learning Explainable Rules for Recommendation with Knowledge Graph](https://dl.acm.org/authorize?N672219).<b style="color:red">[valuable]</b> Weizhi Ma (Tsinghua University, China); Min Zhang (Tsinghua University, China); Yue Cao (University of Southern California, United States); Woojeong Jin (University of Southern California, United States); Chenyang Wang (Tsinghua University, China); Yiqun Liu (Tsinghua University, China); Shaoping Ma (Tsinghua University, China); Xiang Ren (University of Southern California, United States)
#     * Que: explainable and efficience
#       1. only performance emphisized
#       1. explainable --> prediction by NN is hard to explain and debug
#       1. effectiveness --> manually design metapath like HINRec is burdensome
#     * Method: joint learning = rule learning module + RecSys module
#       1. effectiveness --> rule learning from KG
#       1. explainable --> rule-guided neural RecSys
#     * Dataset:
#       1. Freebase
#       1. Amazon cellphone
#       1. Amazon electronic
#     * Summary:
#       1. unexpected --> confusion is somehow mistake
#       1. this work is relation-directed, apart from previous work, which is node-directed and
#          relation is neglected or just offers link information.
